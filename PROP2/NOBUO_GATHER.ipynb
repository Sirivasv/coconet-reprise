# %%
import os
import numpy as np
import music21 as m21
import pandas as pd
import json
import matplotlib.pyplot as plt
import time

np.random.seed(777)

# %% [markdown]
# ## Functions

# %%
DIV_CONST = 10

# %%
def getSongKey(song):
    key = song.analyze("key")
    return key

# %%
def getSongKeyFromMelody_W_Times(melody_w_times_in_k):
    sc_test = m21.stream.Score()
    p0_test = m21.stream.Part()
    p0_test.id = 'part0'
    for pitch_i in melody_w_times_in_k:
        n_i = m21.note.Note(pitch_i[4])
        p0_test.append(n_i)
    sc_test.insert(0, p0_test)
    return getSongKey(sc_test)

# %%
# Function to retrieve a list of midi pitch events and its timestamp
def getMelodyDeltaTimes(eventsintrack):
    
    # Initialize array
    DeltaTimes = []
    
    # Initialize cumulative sum
    cum_sum = 0
    
    # Initialize variable to track the time delta
    prev_deltatime = 0
    
    # Traverse the events
    for ev in eventsintrack:
        
        # If a note starts
        if (ev.isNoteOn()):
        
            
            # Get the pitch name and save it with the cumulative sum, midi pitch and name
            pitch_in_time = m21.pitch.Pitch(ev.pitch)
            DeltaTimes.append((cum_sum, prev_deltatime, pitch_in_time.midi, pitch_in_time.spanish, pitch_in_time))
            
            # Restart the delta time
            prev_deltatime = 0
        
        # Else if there is a delta time
        elif(str(ev.type) == "DeltaTime"):
          
            # We sum the time
            cum_sum += ev.time
            
            # We sum it to the current delta time
            prev_deltatime += ev.time
    
    # Return the array
    return DeltaTimes

# %%
def get_SCLM_v100(melody_w_times_A, melody_w_times_B):
    
    # We use a Dynamic Programming approach
    max_len = max(len(melody_w_times_A), len(melody_w_times_B)) + 1
    
    # memoization array
    memo = np.full(shape=(max_len,max_len), fill_value=-1)
    
    # Get the limits for each melody
    lim_A = len(melody_w_times_A)
    lim_B = len(melody_w_times_B)
    
    # Actual DP implementation
    for i in range(lim_A, -1, -1):
        for j in range(lim_B, -1, -1):
            
            # If we are at the limits the solution is 0
            if i == lim_A or  j == lim_B:
                memo[i][j] = 0
                continue
            
            # If there is a match a possible solution is the previous plus one
            curr_value = 0
            
            tot_delta_time = (float(melody_w_times_A[i][1]) + float(melody_w_times_B[j][1])) / float(DIV_CONST)
            tot_diff_time = np.abs(float(melody_w_times_A[i][1]) - float(melody_w_times_B[j][1]))
            
            
            if (melody_w_times_A[i][3] == melody_w_times_B[j][3]) and (tot_diff_time <= tot_delta_time):
                curr_value = memo[i + 1][j + 1] + 1
                
            # The actual solution is the maximum between the one if there is a match, or skip on the melody A or melody B
            curr_value = max(curr_value, max(memo[i + 1][j], memo[i][j + 1]))
            
            # Save the solution
            memo[i][j] = curr_value
    
    # With the memoization table we can retrieve the actual melody
    i = 0
    j = 0
    SCLM = []
    while i != lim_A and j != lim_B:
    
        if ((memo[i + 1][j + 1] + 1) == memo[i][j]):
            SCLM.append((i, j))
            i += 1
            j += 1
        elif (memo[i + 1][j] == memo[i][j]):
            i += 1
        elif (memo[i][j + 1] == memo[i][j]):
            j += 1
    
    return SCLM

# %%
def get_max_timestamp_dif(melody_w_times_A, melody_w_times_B):
    return max(
        melody_w_times_A[len(melody_w_times_A) - 1][0] - melody_w_times_A[0][0],
        melody_w_times_B[len(melody_w_times_B) - 1][0] - melody_w_times_B[0][0]
    )

# %%
def getDifSCLM(melody_w_times_A, melody_w_times_B, sclm):
    
    # If there is no sclm or it is just one return max possible value
    if (len(sclm) <= 1):
        return get_max_timestamp_dif(melody_w_times_A, melody_w_times_B)
    
    
    # Initialize the arrays
    T_A = np.zeros(shape=(len(sclm) - 1))
    T_B = np.zeros(shape=(len(sclm) - 1))
    T_C = np.zeros(shape=(len(sclm) - 1))
    Dif_ = np.zeros(shape=(len(sclm) - 1))
    
    for i in range(1, len(sclm)):
        T_A[i - 1] = melody_w_times_A[sclm[i][0]][0] - melody_w_times_A[sclm[i-1][0]][0]
        T_B[i - 1] = melody_w_times_B[sclm[i][1]][0] - melody_w_times_B[sclm[i-1][1]][0]
        T_C[i - 1] = np.abs(T_A[i - 1] - T_B[i - 1])
    
    T_C_mean = np.mean(T_C)
    
    for i in range(0, len(T_B)):
        T_B[i] += T_C_mean
        Dif_[i] = T_A[i] - T_B[i]
    
    return T_C_mean

# %%
def get_MTRC_v100_from_melody_w_times(melody_w_times_A, melody_w_times_B):
    
    # Assert at least one element for each melody
    if (len(melody_w_times_A) == 0 or len(melody_w_times_B) == 0):
        print("EMPTY")
        return 1
    
    # Initialize result variable
    result_value = 0
    
    # Get Keys
    key_A = getSongKeyFromMelody_W_Times(melody_w_times_A)
    key_B = getSongKeyFromMelody_W_Times(melody_w_times_B)
    
    # D1: Scale  
    scale_dif1 = 0
    if (key_A.name != key_B.name):
        scale_dif1 = W1
    result_value += scale_dif1
    
    # D2: Mode  
    mode_dif2 = 0
    if (key_A.mode != key_B.mode):
        mode_dif2 = W2
    result_value += mode_dif2
    
    # Get SCLM v100
    sclm = get_SCLM_v100(melody_w_times_A, melody_w_times_B)
    
    # Get max len
    max_len = max(len(melody_w_times_A), len(melody_w_times_B))
    
    # D3: SCLM Length
    sclmlen_dif3 = ((max_len - len(sclm)) / max_len) * W3
    result_value += sclmlen_dif3
    
    # Get the Diff on temporal spacing in the SCLM
    dif_sclm = getDifSCLM(melody_w_times_A, melody_w_times_B, sclm)
    
    # D4: dif in sclm
    max_timestamp_dif = get_max_timestamp_dif(melody_w_times_A, melody_w_times_B)
    sclmdif_dif4 = (dif_sclm / max_timestamp_dif) * W4
    result_value += sclmdif_dif4
    
    return result_value

# %% [markdown]
# ## Traverse DATA

# %%
## NES ##
NOBUO_DATASET_PATH = "/Users/diego/unam/2021-I/aprendizaje_profundo/proyecto/nobuo/"

# %%
# Traverse midi files
nes_song_filenames = []
for root, directories, files in os.walk(NOBUO_DATASET_PATH):
    for file in files:
        nes_song_filenames.append(file)
print(nes_song_filenames[:3])
print(len(nes_song_filenames))
# Out:
# ["FF6-_Devil's_Lab.mid", 'YGM - 4-04 A Secret, Sleeping in the Deep Sea.mid', "GM - 1-21 Red XIII's Theme.mid"]
# 1060

# %%
# %%time

W1 = 0.0
W2 = 0.0
W3 = 1.0
W4 = 0.0

# Read Files 
MAX_LIM_NES_SONGS = len(nes_song_filenames)
len_nes_song_filenames = len(nes_song_filenames)
nes_songs_with_error = []
nes_similarities_for_sort = []


# Query File
# "322_SuperMarioBros__02_03SwimmingAround.mid"
# "322_SuperMarioBros__10_11SavedthePrincess.mid"
# "339_Tetris_00_01TitleScreen.mid"
song_filename_query = "007S-END.mid"
song_stream_query = m21.converter.parseFile(os.path.join(NOBUO_DATASET_PATH, song_filename_query))
midi_tracks_query = m21.midi.translate.streamToMidiFile(song_stream_query)
melody_w_times_query = getMelodyDeltaTimes(midi_tracks_query.tracks[1].events)

# We traverse the reduced table
cnt = 1
for song_filename_test in nes_song_filenames:
    try:
        
        song_stream_test = m21.converter.parseFile(os.path.join(NOBUO_DATASET_PATH, song_filename_test))
        midi_tracks_test = m21.midi.translate.streamToMidiFile(song_stream_test)
        melody_w_times_test = getMelodyDeltaTimes(midi_tracks_test.tracks[1].events)

        similarity_distance = get_MTRC_v100_from_melody_w_times(
            melody_w_times_query,
            melody_w_times_test)
        
        nes_similarities_for_sort.append((song_filename_test, similarity_distance))
        
        with open('./PROP2_query_to_sort_{0}.json'.format(song_filename_query.split(".")[0]), 'w') as outfile:
            json.dump({"data":nes_similarities_for_sort}, outfile)
        
    except:
        print("[ERROR!]")
        nes_songs_with_error.append(song_filename_test)
    finally:
        print("{0}/{1} - {2} - {3}".format(cnt, len_nes_song_filenames, song_filename_test, similarity_distance))
        cnt += 1
        if (cnt == MAX_LIM_NES_SONGS):
            break
# Out:
#  - TerraMix.mid - 1.0
# 672/1060 - Phantomf.mid - 1.0
# 673/1060 - ff9-02-11-at_the_south_gate_border.mid - 0.9696969696969697
# 674/1060 - XG - 3-23 Who Am I.mid - 0.9947916666666666
# 675/1060 - ff2lsub.mid - 0.9857142857142858
# 676/1060 - FF3Boss.mid - 0.9895833333333334
# 677/1060 - 064s-choco.mid - 0.9845679012345679
# 678/1060 - Ff6dance.mid - 1.0
# 679/1060 - ff9-01-22-gameover.mid - 0.7632508833922261
# 680/1060 - ff2babil.mid - 0.9114583333333334
# 681/1060 - 121-The Trial.mid - 0.9807692307692307
# 682/1060 - Ff4airsh.mid - 0.9866666666666667
# 683/1060 - YGM - 2-15 Conitnue.mid - 0.9947916666666666
# 684/1060 - 048s-horizon.mid - 1.0
# 685/1060 - YGM - 3-07 Cid's Theme.mid - 0.9895833333333334
# 686/1060 - YGM - 2-04 On That Day, 5 Years Ago.mid - 0.9947916666666666
# 687/1060 - XG - 1-04 Anxious Heart.mid - 1.0
# 688/1060 - GM - 2-18 Mining Town.mid - 1.0
# 689/1060 - celes.mid - 0.9895833333333334
# 690/1060 - GM - 1-06 Barett's Theme.mid - 0.9322916666666666
# 691/1060 - 099s-joriku2.mid - 0.9947916666666666
# 692/1060 - ff6shap.mid - 0.9947916666666666
# 693/1060 - 012s-kani.mid - 0.9947916666666666
#  ('YGM - 2-14 J-E-N-O-V-A.mid', 1.0),
#  ('ff3over5.mid', 1.0),
#  ('GM - 1-17 Who Are You.mid', 1.0),
#  ('308-Undersea Palace.mid', 0.8729641693811075),
#  ('ff9-02-09-ukele_le_chocobo.mid', 0.9360655737704918),
#  ('setzer2.mid', 0.9429928741092637),
#  ('GM - 2-04 On That Day, 5 Years Ago.mid', 0.9947916666666666),
#  ('XG - 2-06 Waltz de Chocobo.mid', 0.9947916666666666),
#  ('ff2under.mid', 0.984375),
#  ('ff6final4.mid', 1.0),
#  ('ff9-04-10-endless_sorrow.mid', 0.9903303787268332),
#  ('AWE - 4-08 Hurry Faster!.mid', 0.9788135593220338),
#  ('YGM - 4-14 Jenova Absolute.mid', 1.0),
#  ('locke2.mid', 0.9403409090909091),
#  ('055s-jail.mid', 1.0),
#  ('ff3cyan_the.mid', 0.9791666666666666),
#  ('finalfant2.mid', 1.0),
#  ('XG - 1-08 Lurking in the Darkness.mid', 1.0),
#  ('ff9-04-12-skirmish_with_the_silver_dragons.mid', 0.9659498207885304),
#  ('Celes_Kiss_Me.mid', 0.984375),
#  ('YGM - 1-08 Lurking in the Darkness.mid', 1.0),
#  ('ff6battle.mid', 0.9822222222222222),
#  ('AWE - 4-06 Off the Edge of Dispair.mid', 1.0),
#  ("107-Gato's Song.mid", 0.9895833333333334),
#  ('Giott.mid', 0.9114583333333334),
#  ('ff9-01-04-the_skies_of_alexandria.mid', 0.9947916666666666),
#  ('YGM - 4-08 Hurry Faster!.mid', 0.9789029535864979),
#  ('PHANTOMT.mid', 0.9895833333333334),
#  ('ff2lunar.mid', 1.0),
#  ('GM - 2-10 Fortress of the Condor.mid', 0.9739583333333334),
#  ('GM - 3-21 The Great Northern Cave .mid', 0.9947916666666666),
#  ('GM - 3-04 Descendant of Shinobi.mid', 0.9947916666666666),
#  ('304-Time Circuits.mid', 0.9683257918552036),
#  ('Ff4wtown.mid', 0.984375),
#  ('AWE - 1-01 Prelude.mid', 1.0),
#  ('Grand_Finale_Part_B.mid', 0.9888535031847133),
#  ('locke3.mid', 0.96875),
#  ('049s-master.mid', 0.9947916666666666),
#  ("AWE - 1-13 Turk's Theme.mid", 1.0),
#  ('ff6final5.mid', 0.9994169096209913),
#  ('setzer3.mid', 0.9771341463414634),
#  ('ff6locke.mid', 0.9895833333333334),
#  ('GM - 1-04 Anxious Heart .mid', 1.0),
#  ('316-Epilogue - To Good Friends.mid', 0.9479166666666666),
#  ('dayafter1.mid', 0.9704861111111112),
#  ("ff9-03-08-eiko's_theme.mid", 0.9904761904761905),
#  ('dvlslab.mid', 1.0),
#  ('YGM - 2-17 Mark of the Traitor.mid', 0.9895833333333334),
#  ('078s-garfly.mid', 0.8921568627450981),
#  ('ff3over4.mid', 0.9947916666666666),
#  ("GM - 2-12 It's Difficult to Stand on Both Feet, Isn't It.mid", 0.984375),
#  ('figaro2.mid', 0.9947916666666666),
#  ('ballad.mid', 1.0),
#  ('086s-moonmv.mid', 0.9947916666666666),
#  ('GM - 4-04 A Secret, Sleeping in the Deep Sea.mid', 1.0),
#  ('xmidff6boss.mid', 0.9503171247357294),
#  ('LunCave.mid', 1.0),
#  ("XG - 2-12 It's Difficult to Stand on Both Feet, Isn't It.mid", 0.984375),
#  ('magitek3.mid', 1.0),
#  ('surprise.mid', 1.0),
#  ('setzer.mid', 0.9203187250996016),
#  ('Rachel.mid', 0.9895833333333334),
#  ('YGM - 3-01 Cosmo Canyon.mid', 0.9114583333333334),
#  ('YGM - Bonus - Highwind Takes to the Skies Intro.mid', 0.9947916666666666),
#  ("203-Dome 16's Ruin.mid", 1.0),
#  ('YGM - 3-11 Racing Chocobos-Place Your Bets.mid', 0.9583333333333334),
#  ('mysidiax.mid', 0.9937694704049844),
#  ('YGM - 3-04 Descendant of Shinobi.mid', 0.953125),
#  ('036s-majo.mid', 1.0),
#  ("ff9-03-17-mogri's_theme.mid", 0.859375),
#  ('ff9-02-08-aloha_de_chocobo.mid', 0.9875968992248062),
#  ('Awakening.mid', 0.8793103448275862),
#  ('Predance.mid', 0.9445519019987105),
#  ('ff4_fiend.mid', 0.9907651715039578),
#  ('ff9-04-15-messenger_of_destruction.mid', 0.9824686093342809),
#  ('XG - 1-15 Opressed People.mid', 0.984375),
#  ('YGM - 3-17 Forested Temple.mid', 0.984375),
#  ('XG - 3-20 Buried in the Snow.mid', 0.9895833333333334),
#  ('204-People Without a Hope.mid', 0.9947916666666666),
#  ('AWE - Bonus - Bombing Mission.mid', 0.984375),
#  ('cecil_he.mid', 0.9913793103448276),
#  ("FF6-_Kefka's_Theme.mid", 0.9865996649916248),
#  ('baronmix.mid', 0.9645494830132939),
#  ('FFIIIprelude.mid', 0.9362980769230769),
#  ('218-Primitive Mountain.mid', 0.9667590027700831),
#  ('103-Morning Sunlight.mid', 0.9947916666666666),
#  ("XG - 2-11 Rufus's Welcoming Ceremony.mid", 0.9066666666666666),
#  ('093s-lasboss.mid', 0.9010416666666666),
#  ('FF2-Big_Boss.mid', 0.9810022026431718),
#  ('ff9-01-02-memories_lost_in_the_storm.mid', 0.984375),
#  ('GM - 1-03 Makou Reactor.mid', 1.0),
#  ('XG - Bonus - Xg023.mid', 0.9947916666666666),
#  ('AWE - 2-10 Fortress of the Condor.mid', 0.9739583333333334),
#  ('ff6final1.mid', 0.9988776655443322),
#  ('311-Black Omen.mid', 0.9923469387755102),
#  ('123-A Shot of Crisis.mid', 0.9739583333333334),
#  ('fanfare.mid', 0.9962546816479401),
#  ('317-To Far Away Times.mid', 0.9891500904159132),
#  ('096s-keisho.mid', 0.9947916666666666),
#  ("AWE - 3-06 The Nightmare's Beginning.mid", 0.984375),
#  ('edward2.mid', 1.0),
#  ('XG - 2-08 Cinco de Chocobo.mid', 0.9895833333333334),
#  ('TerraMix.mid', 1.0),
#  ('Phantomf.mid', 1.0),
#  ('ff9-02-11-at_the_south_gate_border.mid', 0.9696969696969697),
#  ('XG - 3-23 Who Am I.mid', 0.9947916666666666),
#  ('ff2lsub.mid', 0.9857142857142858),
#  ('FF3Boss.mid', 0.9895833333333334),
#  ('064s-choco.mid', 0.9845679012345679),
#  ('Ff6dance.mid', 1.0),
#  ('ff9-01-22-gameover.mid', 0.7632508833922261),
#  ('ff2babil.mid', 0.9114583333333334),
#  ('121-The Trial.mid', 0.9807692307692307),
#  ('Ff4airsh.mid', 0.9866666666666667),
#  ('YGM - 2-15 Conitnue.mid', 0.9947916666666666),
#  ('048s-horizon.mid', 1.0),
#  ("YGM - 3-07 Cid's Theme.mid", 0.9895833333333334),
#  ('YGM - 2-04 On That Day, 5 Years Ago.mid', 0.9947916666666666),
#  ('XG - 1-04 Anxious Heart.mid', 1.0),
#  ('GM - 2-18 Mining Town.mid', 1.0),
#  ('celes.mid', 0.9895833333333334),
#  ("GM - 1-06 Barett's Theme.mid", 0.9322916666666666),
#  ('099s-joriku2.mid', 0.9947916666666666),
#  ('ff6shap.mid', 0.9947916666666666),
#  ('012s-kani.mid', 0.9947916666666666),
#  ("XG - 3-07 Cid's Theme.mid", 0.9895833333333334),
#  ("AWE - 2-20 Cait Sith's Theme.mid", 0.9901477832512315),
#  ('ff9-04-16-final_battle.mid', 0.9895833333333334),
#  ("ff9-01-10-steiner's_theme.mid", 0.9739583333333334),
#  ('315-First Festival of Stars.mid', 0.992619926199262),
#  ('ff9-04-08-pandemonium.mid', 0.9895833333333334),
#  ('Ff2airsh(2).mid', 0.984375),
#  ('XG - Bonus - FFVII Main Theme Second Half.mid', 0.9950248756218906),
#  ('XG - 2-09 Chasing the Black-Caped Man.mid', 1.0),
#  ('Ff3kfkt1.mid', 1.0),
#  ('YGM - 2-19 Gold Saucer.mid', 0.8854166666666666),
#  ('ff9-02-16-the_sword_of_mystery.mid', 0.9982456140350877),
#  ('magitek4.mid', 0.9947916666666666),
#  ('opera.mid', 0.9895833333333334),
#  ('ff3over3.mid', 1.0),
#  ('KIDSRUN(2).mid', 0.9947916666666666),
#  ('XG - 2-16 Costa Del Sol.mid', 1.0),
#  ('ragde.mid', 0.9817850637522769),
#  ('XG - 1-10 Fighting.mid', 0.9521410579345088),
#  ('Ff3gogo.mid', 0.9947916666666666),
#  ('ff_4jazzchocobo.mid', 0.9712643678160919),
#  ('XG - 2-19 Gold Saucer.mid', 0.8854166666666666),
#  ('veldt2.mid', 0.9535017221584385),
#  ('AWE - 3-21 The Great Northern Cave.mid', 0.9947916666666666),
#  ('FF2-Victory.mid', 0.9739583333333334),
#  ('Rydia_pc.mid', 0.9926470588235294),
#  ('GM - 1-07 Hurry!.mid', 0.9947916666666666),
#  ('Celes1.mid', 0.984375),
#  ('3-07-SearchingForFriends.mid', 0.9895833333333334),
#  ('GM - 4-08 Hurry Faster!.mid', 0.9788135593220338),
#  ('Ff3_mgtk.mid', 0.827485380116959),
#  ('Locke_Remix.mid', 0.9827586206896551),
#  ('ff2pp.mid', 0.9114583333333334),
#  ('ff6final2.mid', 0.9910923581809657),
#  ('053s-antena2.mid', 0.9635416666666666),
#  ('atma.mid', 0.9424778761061947),
#  ('ff9-03-02-rose_of_may.mid', 0.9965277777777778),
#  ('Ff4toror.mid', 0.9947916666666666),
#  ('kidsrun.mid', 0.9947916666666666),
#  ('owzer.mid', 1.0),
#  ('ff9-01-11-prima_vista_band.mid', 1.0),
#  ('ffgeetar.mid', 0.9408866995073891),
#  ('GM - 4-06 Off the Edge of Dispair.mid', 1.0),
#  ("AWE - 2-11 Rufus's Welcoming Ceremony.mid", 0.9066666666666666),
#  ('YGM - 1-12 Flowers Blooming in the Church.mid', 0.9895833333333334),
#  ('opera2.mid', 0.9895833333333334),
#  ('veldt.mid', 0.8854166666666666),
#  ('ff9-03-03-fossil_roo.mid', 1.0),
#  ('AWE - 4-03 Highwind Takes to the Skies.mid', 0.9635416666666666),
#  ('Phantom.mid', 1.0),
#  ('YGM - 1-02 Opening ~ Bombing Mission.mid', 0.9791666666666666),
#  ("YGM - 1-05 Tifa's Theme.mid", 0.9895833333333334),
#  ('FF6_-_Locke1.mid', 0.9739583333333334),
#  ('AWE - 4-11 If You Open Your Heart....mid', 0.984375),
#  ('Evil_Chocobo_Theme.mid', 0.8700440528634361),
#  ('YGM - Bonus - Hearthbeat.mid', 1.0),
#  ('ff6final3.mid', 0.9902152641878669),
#  ('AWE - Bonus - Heartbeat.mid', 1.0),
#  ("ff9-02-15-kuja's_theme.mid", 1.0),
#  ('cyanSq.mid', 0.9739583333333334),
#  ('AWE - 1-23 Holding My Thoughts in My Heart.mid', 0.9947916666666666),
#  ('Fabul.mid', 0.9947916666666666),
#  ('ff4fiend.mid', 0.9670781893004116),
#  ('BosNovCh.mid', 0.9895833333333334),
#  ('Ff4bat2.mid', 0.9931389365351629),
#  ('XG - 2-10 Fortress of the Condor.mid', 0.9739583333333334),
#  ('YGM - 4-12 The Makou Cannon is Fired ~ ShinRa Explodes.mid',
#   0.9947916666666666),
#  ('Ff3fnfar.mid', 0.9947916666666666),
#  ('YGM - 1-20 Still More Fighting.mid', 0.9043478260869565),
#  ('gau.mid', 1.0),
#  ('figaro4.mid', 0.8969465648854962),
#  ('GM - 1-23 Holding My Thoughts in My Heart.mid', 0.9947916666666666),
#  ('ff3over2.mid', 0.6717171717171717),
#  ('chocobo.mid', 0.9830167597765364),
#  ('GM - 1-12 Flowers Blooming in the Church.mid', 0.9895833333333334),
#  ('XG - 4-04 A Secret, Sleeping in the Deep Sea .mid', 1.0),
#  ('GM - 2-08 Cinco de Chocobo.mid', 0.9895833333333334),
#  ('ffmxrest.mid', 0.9070680628272252),
#  ('ff2end.mid', 0.9975308641975309),
#  ('YGM - 2-07 Electric de Chocobo.mid', 0.9613899613899614),
#  ('kefka.mid', 0.9635416666666666),
#  ('310-Epoch Wings that Cross Time.mid', 0.96875),
#  ('Ff4fld1.mid', 0.9845984598459846),
#  ('YGM - 2-21 Sandy Badlands.mid', 1.0),
#  ('AWE - 3-08 Steal the Tiny Bronco!.mid', 0.9895833333333334),
#  ('Ff3figar1.mid', 1.0),
#  ('AWE - 2-05 Farm Boy.mid', 0.9947916666666666),
#  ('XG - 3-16 Interupted by Fireworks.mid', 1.0),
#  ('YGM - 3-16 Interupted by Fireworks.mid', 1.0),
#  ('ff2end3.mid', 1.0),
#  ('returner.mid', 0.9666666666666667),
#  ('303-At the Bottom of the Night.mid', 0.984375),
#  ('YGM - 3-12 Fiddle de Chocobo.mid', 0.9354005167958657),
#  ('GM - 1-16 Honeybee Manor.mid', 0.7916666666666666),
#  ('FF2-Dreadful.mid', 0.966),
#  ('FF4Fiend2.mid', 0.9402597402597402),
#  ('AWE - Bonus - Those Chosen by the Planet No Intro.mid', 0.9895833333333334),
#  ('ff2dmcyn(2).mid', 1.0),
#  ('The_Wedding_Waltz_Duel_Part_D.mid', 0.9982238010657194),
#  ('YGM - Bonus - Unknown 2.mid', 0.9947916666666666),
#  ('cecil.mid', 0.9913793103448276),
#  ('115-Manoria Cathedral.mid', 0.9947916666666666),
#  ('ff9-01-16-queen_of_the_abyss.mid', 0.984375),
#  ('YGM - Bonus - Short Fanfare.mid', 0.9947916666666666),
#  ('XG - 4-16 One Winged Angel.mid', 0.9709794437726723),
#  ('005s-battle.mid', 0.9947916666666666),
#  ("FF6-_Setzer's_Theme.mid", 0.9235807860262009),
#  ("GM - 3-19 Aerith's Theme.mid", 0.9895833333333334),
#  ('calbrena.mid', 1.0),
#  ('AWE - 3-05 Those Chosen by the Planet.mid', 0.9895833333333334),
#  ("ff9-04-09-you're_not_alone.mid", 1.0),
#  ('085s-esta.mid', 1.0),
#  ('shadow3.mid', 0.9947916666666666),
#  ('jpr-terramixgm.mid', 0.984375),
#  ('AWE - 1-02 Opening ~ Bombing Mission.mid', 0.984375),
#  ('YGM - 4-11 If You Open Your Heart....mid', 0.984375),
#  ('at-zero.mid', 0.9901356350184957),
#  ('shadow2.mid', 0.9895833333333334),
#  ('ff9-01-13-tonight.mid', 0.9947916666666666),
#  ('ff2airsh.mid', 0.984375),
#  ('YGM - 2-01 FFVII Main Theme.mid', 0.9912663755458515),
#  ('013s-battle2.mid', 0.9739583333333334),
#  ('XG - 1-22 Crazy Motorcycle.mid', 0.9947916666666666),
#  ('ff3unfor.mid', 0.8779979144942649),
#  ("XG - 1-13 Turk's Theme.mid", 1.0),
#  ('ff3btlre.mid', 0.9132231404958677),
#  ('spinach.mid', 0.9333777481678881),
#  ('ff9-02-26-extraction.mid', 1.0),
#  ('Ff3zozo.mid', 0.9791666666666666),
#  ('terremix.mid', 0.91015625),
#  ('ff2-the_paladin.mid', 1.0),
#  ('XG - 4-14 Jenova Absolute.mid', 1.0),
#  ("FF6_-_Devil's_Lab.mid", 1.0),
#  ('XG - 3-04 Descendant of Shinobi .mid', 0.9947916666666666),
#  ('XG - 3-11 Racing Chocobos-Place Your Bets.mid', 0.9583333333333334),
#  ('042s-guitar.mid', 0.9895833333333334),
#  ('esper2.mid', 1.0),
#  ('Espers.mid', 1.0),
#  ('YGM - Bonus - Unknown 3.mid', 1.0),
#  ('212-Fanfare 2.mid', 1.0),
#  ('ff3mog.mid', 0.9905660377358491),
#  ('XG - 2-15 Conitnue.mid', 0.9947916666666666),
#  ('GM - 2-09 Chasing the Black-Caped Man.mid', 1.0),
#  ('GM - 2-03 Good Night, Until Tommorow.mid', 1.0),
#  ('relm4.mid', 0.9895833333333334),
#  ('YGM - 2-16 Costa Del Sol.mid', 1.0),
#  ('babil.mid', 0.9972714870395635),
#  ('GM - 4-01 ShinRa Army Wages a Full Scale Attack.mid', 0.9166666666666666),
#  ('ballad2.mid', 0.9895833333333334),
#  ('ff9-01-23-run.mid', 0.9671361502347418),
#  ('FFIVSusp.mid', 1.0),
#  ('YGM - 3-23 Who Am I.mid', 0.9947916666666666),
#  ('YGM - 4-03 Highwind Takes to the Skies.mid', 0.9635416666666666),
#  ('shadow.mid', 0.9947916666666666),
#  ('AWE - 2-16 Costa Del Sol.mid', 1.0),
#  ('AWE - 3-13 A Great Success.mid', 0.984375),
#  ('000s-lose.mid', 1.0),
#  ('ff9-02-23-cleyra_settlement.mid', 1.0),
#  ('XG - 1-11 Fanfare.mid', 1.0),
#  ('GM - 1-22 Crazy Motorcycle.mid', 0.9947916666666666),
#  ('057s-timber.mid', 0.9742489270386266),
#  ('AWE - 1-04 Anxious Heart.mid', 1.0),
#  ('FF6-_Overworld_Theme.mid', 0.7290969899665551),
#  ('GM - 2-17 Mark of the Traitor.mid', 0.9895833333333334),
#  ('seal.mid', 0.9897540983606558),
#  ('AWE - 2-15 Continue.mid', 0.9947916666666666),
#  ("119-Frog's Theme.mid", 0.9947916666666666),
#  ('ff9-03-25-gulgur_volcano.mid', 0.9977272727272727),
#  ('AWE - 2-06 Waltz de Chocobo.mid', 0.9947916666666666),
#  ('YGM - 1-04 Anxious Heart.mid', 1.0),
#  ('YGM - Bonus - Unknown 1.mid', 0.9895833333333334),
#  ('YGM - 1-18 Don of the Slums.mid', 0.9947916666666666),
#  ('ff9-01-09-jesters_of_the_moonless_sky.mid', 0.9611650485436893),
#  ('IdiotFF3Airship.mid', 0.9904306220095693),
#  ('GM - Bonus - Comical.mid', 0.9895833333333334),
#  ('046s-resistan.mid', 0.9895833333333334),
#  ('12-IntoTheDarkness.mid', 0.9923371647509579),
#  ('GM - 3-13 A Great Success.mid', 0.984375),
#  ('ff6-ShadowsTheme2.mid', 0.9526315789473684),
#  ('GM - 3-14 Tango of Tears.mid', 0.9895833333333334),
#  ('FF6-_Victory_Fanfare.mid', 0.9947916666666666),
#  ('070s-card.mid', 1.0),
#  ('YGM - 4-02 Weapon Raid.mid', 1.0),
#  ("YGM - 3-06 The Nightmare's Beginning.mid", 0.8664772727272727),
#  ('Save_Them.mid', 0.9644549763033176),
#  ('ff3over.mid', 1.0),
#  ('XG - 2-21 Sandy Badlands.mid', 1.0),
#  ('ff9-04-11-the_evil_mist_again.mid', 1.0),
#  ('ff9-01-08-decisive_action~search_for_the_princess~.mid', 0.993103448275862),
#  ('Intodark.mid', 0.9944289693593314),
#  ('Ff3shadrem.mid', 1.0),
#  ('XG - 4-02 Weapon Raid.mid', 0.9947916666666666),
#  ('ff9-03-05-black_mage_village.mid', 0.9676584734799483),
#  ('YGM - Bonus - FFVII Main Theme Second Half.mid', 0.9950248756218906),
#  ('cyan.mid', 0.9791666666666666),
#  ('ff3town.mid', 0.9981549815498155),
#  ('ff3-mtkoltz.mid', 0.984375),
#  ('atma4.mid', 0.9977064220183486),
#  ('041s-field.mid', 0.9947916666666666),
#  ('awaken.mid', 0.984375),
#  ('GM - 4-16 One Winged Angel.mid', 0.9024390243902439),
#  ('fatchoc.mid', 0.9895833333333334),
#  ("GM - 1-13 Turk's Theme.mid", 1.0),
#  ('YGM - 3-09 Wuati.mid', 0.9947916666666666),
#  ('101-A Premonition.mid', 1.0),
#  ('World1.mid', 0.967687074829932),
#  ('kefka2.mid', 0.9895833333333334),
#  ('ff2end1.mid', 0.96875),
#  ('Terra5.mid', 0.90625),
#  ('Baron(2).mid', 0.961038961038961),
#  ('XG - 3-08 Steal the Tiny Bronco!.mid', 0.9916317991631799),
#  ('YGM - 2-03 Good Night, Until Tommorow.mid', 1.0),
#  ('112-Battle Theme 1.mid', 0.9895833333333334),
#  ('AWE - 2-21 Sandy Badlands .mid', 1.0),
#  ('047s-kaiso.mid', 0.9895833333333334),
#  ('Toria.mid', 0.9553030303030303),
#  ('AWE - 2-18 Mining Town.mid', 1.0),
#  ('FF6_-_The_Unforgiven.mid', 0.8143100511073254),
#  ('AWE - 2-08 Cinco de Chocobo.mid', 0.9895833333333334),
#  ('081s-mods.mid', 0.9895833333333334),
#  ('ff9-02-03-lindbulm.mid', 0.9895833333333334),
#  ('AWE - 1-17 Who Are You.mid', 1.0),
#  ('zozo1.mid', 0.995575221238938),
#  ('120-Fanfare 1.mid', 0.9947916666666666),
#  ('ff9-03-10-walls_of_the_sacred_beasts.mid', 1.0),
#  ('018s-julia.mid', 0.9947916666666666),
#  ('080S-SPY.MID', 0.828125),
#  ('Terra1.mid', 0.9947916666666666),
#  ('ff9-02-04-song_of_memories.mid', 0.9907407407407407),
#  ('jcbaddp.mid', 0.9405204460966543),
#  ('GM - 4-09 Sending a Dream Into the Universe.mid', 0.9895833333333334),
#  ('AWE - 3-12 Fiddle de Chocobo.mid', 0.9247648902821317),
#  ('relm3.mid', 0.984375),
#  ('ff4Rydia.mid', 0.9947916666666666),
#  ('GM - 3-05 Those Chosen by the Planet.mid', 0.9895833333333334),
#  ("ff9-01-31-zidane's_theme.mid", 0.9985815602836879),
#  ('ff9-03-01-ambush_attack.mid', 0.9946341463414634),
#  ('ff9-02-12-fairy_battle.mid', 0.9951690821256038),
#  ('Hey,_Cid!.mid', 0.9166666666666666),
#  ('YGM - Bonus - Those Chosen by the Planet No Intro.mid', 0.9895833333333334),
#  ('ff2_ring_of_bomb.mid', 0.9947916666666666),
#  ('Rydia.mid', 0.9947916666666666),
#  ('bossbatt.mid', 0.8798076923076923),
#  ('063s-stage.mid', 1.0),
#  ('ff9-02-21-ancient_passageway-gargan_roo.mid', 0.9964476021314387),
#  ('FF6-_Zozo.mid', 0.9973614775725593),
#  ('DougsTheme.mid', 0.9880650076180802),
#  ('GM - 1-01 Prelude.mid', 1.0),
#  ('ff6_zozo.mid', 0.8545454545454545),
#  ('YGM - 4-15 The Birth of God.mid', 0.9791666666666666),
#  ('overw.mid', 0.9895833333333334),
#  ('YGM - 3-10 Stolen Materia.mid', 1.0),
#  ('305-Zeal Palace.mid', 0.984375),
#  ("219-Ayla's Theme.mid", 0.9947916666666666),
#  ('Ff3ultros.mid', 0.9915966386554622),
#  ("FF6-_Gogo's_Theme.mid", 0.8809523809523809),
#  ('YGM - Bonus - Bombing Mission.mid', 0.9791666666666666),
#  ('XG - 4-08 Hurry Faster!.mid', 0.9789029535864979),
#  ('ff6figaro.mid', 0.95),
#  ("YGM - 1-21 Red XIII's Theme.mid", 0.8697916666666666),
#  ('AWE - 2-03 Good Night, Until Tommorow.mid', 1.0),
#  ('XG - Bonus - Heartbeat.mid', 1.0),
#  ('esper2r.mid', 1.0),
#  ('ff2town.mid', 0.9739583333333334),
#  ('022s-pianosol.mid', 1.0),
#  ('TheLandOfDwarves.mid', 0.9973958333333334),
#  ('097s-ashuku.mid', 1.0),
#  ('GM - 2-13 Trail of Blood.mid', 0.9947916666666666),
#  ('AWE - 3-10 Stolen Materia.mid', 1.0),
#  ('AWE - 4-01 ShinRa Army Wages a Full Scale Attack.mid', 0.9166666666666666),
#  ('AWE - 1-20 Still More Fighitng.mid', 0.9826086956521739),
#  ('dark2.mid', 0.887719298245614),
#  ('magitek.mid', 1.0),
#  ('FF6-_Awakening.mid', 0.921875),
#  ('118-Boss Battle 1.mid', 0.9739583333333334),
#  ('relm2.mid', 0.9895833333333334),
#  ('Cyan_KJmix.mid', 0.9895833333333334),
#  ('narshe2(2).mid', 0.9956709956709957),
#  ('GM - 3-18 You Can Hear the Cry of the Planet.mid', 1.0),
#  ('GM - 2-02 Ahead on Our Way.mid', 0.9895833333333334),
#  ('015s-fuan2.mid', 0.9947916666666666),
#  ('celes_rnb.mid', 0.984375),
#  ('Ff2bat2b.mid', 0.9752475247524752),
#  ('GM - 2-16 Costa Del Sol.mid', 1.0),
#  ('zozo2.mid', 0.8974358974358975),
#  ('YGM - 3-05 Those Chosen by the Planet.mid', 0.9895833333333334),
#  ('ff2bttle.mid', 0.9635416666666666),
#  ('ff3blackjack.mid', 1.0),
#  ('YGM - Bonus - Ygm061.mid', 1.0),
#  ('202-Mystery of the Path.mid', 1.0),
#  ('ff2cave2.mid', 1.0),
#  ('Ff6batt.mid', 0.9863636363636363),
#  ('GM - 1-20 Still More Fighting.mid', 0.9826086956521739),
#  ('Ff2rosar.mid', 0.9955357142857143),
#  ('XG - 4-07 On the Other Side of the Mountain.mid', 0.9895833333333334),
#  ('ff3tinax.mid', 1.0),
#  ('GM - 2-07 Electric de Chocobo.mid', 0.9739583333333334),
#  ('atma3.mid', 0.9863636363636363),
#  ('FF6_-_Shadow.mid', 1.0),
#  ('Fanfare2.mid', 0.9962546816479401),
#  ('The_Wedding_Waltz_Duel_Part_A.mid', 0.996268656716418),
#  ('114-Huh!.mid', 0.9895833333333334),
#  ('AWE - 2-09 Chasing the Black-Caped Man.mid', 1.0),
#  ('069s-enzetu.mid', 0.9895833333333334),
#  ('FightingaBoss.mid', 0.9545454545454546),
#  ('GM - 4-10 The Countdown Begins.mid', 0.6791666666666667),
#  ('ff2prlde.mid', 1.0),
#  ('AWE - 3-18 You Can Hear the Cry of the Planet.mid', 1.0),
#  ('ff9-03-18-those_whom_we_must_protect.mid', 1.0),
#  ('serpent.mid', 0.9732658959537572),
#  ('FF6_-_(Two_Question_Marks).mid', 0.9689922480620154),
#  ("FF6-_Edgar_&_Sabin's_Theme.mid", 0.9185750636132316),
#  ...]

# %%
nes_similarities_for_sort.sort(key=lambda x: x[1])

# %%
nes_similarities_for_sort
# Out:
# 4),
#  ('XG - 4-07 On the Other Side of the Mountain.mid', 0.9895833333333334),
#  ('114-Huh!.mid', 0.9895833333333334),
#  ('069s-enzetu.mid', 0.9895833333333334),
#  ('XG - 2-02 Ahead on Our Way.mid', 0.9895833333333334),
#  ('3-07-SearchingForFriends-v1.1.mid', 0.9895833333333334),
#  ('GM - 3-20 Buried in the Snow.mid', 0.9895833333333334),
#  ('052s-travia.mid', 0.9895833333333334),
#  ('206-The Day the World Revived.mid', 0.9895833333333334),
#  ('AWE - 4-09 Sending a Dream Into the Universe.mid', 0.9895833333333334),
#  ('214-Delightful Spekkio.mid', 0.9895833333333334),
#  ('XG - 3-09 Wutai.mid', 0.9895833333333334),
#  ('GM - 3-08 Steal the Tiny Bronco!.mid', 0.9895833333333334),
#  ('AWE - 1-12 Flowers Blooming in the Chruch.mid', 0.9895833333333334),
#  ('GM - 3-02 Life Stream.mid', 0.9895833333333334),
#  ('NewContinent.mid', 0.9896907216494846),
#  ('seal.mid', 0.9897540983606558),
#  ('at-zero.mid', 0.9901356350184957),
#  ("GM - 2-20 Cait Sith's Theme.mid", 0.9901477832512315),
#  ("AWE - 2-20 Cait Sith's Theme.mid", 0.9901477832512315),
#  ('ff6final3.mid', 0.9902152641878669),
#  ('ff6-TerrasTheme.mid', 0.9902912621359223),
#  ('Ff2win.mid', 0.9902912621359223),
#  ('ff9-04-10-endless_sorrow.mid', 0.9903303787268332),
#  ('falconhm.mid', 0.9904306220095693),
#  ('ff3Airship.mid', 0.9904306220095693),
#  ('falcon2.mid', 0.9904306220095693),
#  ('IdiotFF3Airship.mid', 0.9904306220095693),
#  ('falcon.mid', 0.9904306220095693),
#  ("ff9-03-08-eiko's_theme.mid", 0.9904761904761905),
#  ('ff3mog.mid', 0.9905660377358491),
#  ('ff3end2.mid', 0.990602975724354),
#  ('ff9-02-04-song_of_memories.mid', 0.9907407407407407),
#  ('ff4_fiend.mid', 0.9907651715039578),
#  ('FF6BATT_changed.mid', 0.990909090909091),
#  ('AWE - Bonus - Unknown 2.mid', 0.9947916666666666),
#  ('Ff3train1.mid', 0.9947916666666666),
#  ('XG - 1-18 Don of the Slums.mid', 0.9947916666666666),
#  ('YGM - 1-09 ShinRa Company.mid', 0.9947916666666666),
#  ('GM - 2-05 Farm Boy.mid', 0.9947916666666666),
#  ('operastg.mid', 0.9947916666666666),
#  ('314-Last Battle.mid', 0.9947916666666666),
#  ('XG - 2-13 Trail of Blood.mid', 0.9947916666666666),
#  ('GM - Bonus - Short Fanfare.mid', 0.9947916666666666),
#  ('AWE - 1-09 ShinRa Company.mid', 0.9947916666666666),
#  ('071s-gomon.mid', 0.9947916666666666),
#  ('YGM - 2-13 Trail of Blood.mid', 0.9947916666666666),
#  ('ff3_daryl.mid', 0.9947916666666666),
#  ('109-Wind Scene.mid', 0.9947916666666666),
#  ('FF_INFINITY.mid', 0.9947916666666666),
#  ('AWE - 4-12 The Makou Cannon is Fired ~ ShinRa Explodes.mid',
#   0.9947916666666666),
#  ('XG - Bonus - Short Fanfare.mid', 0.9947916666666666),
#  ('054s-truth.mid', 0.9947916666666666),
#  ('GM - 2-15 Continue.mid', 0.9947916666666666),
#  ('Locke3(2).mid', 0.9947916666666666),
#  ('YGM - 1-22 Crazy Motorcycle.mid', 0.9947916666666666),
#  ('221-Burn! Bobonga!.mid', 0.9947916666666666),
#  ('XG - 1-09 ShinRa Company.mid', 0.9947916666666666),
#  ('GM - 1-18 Don of the Slums.mid', 0.9947916666666666),
#  ('058s-garbadia.mid', 0.9947916666666666),
#  ('AWE - 2-13 Trail of Blood.mid', 0.9947916666666666),
#  ('title.mid', 0.9947916666666666),
#  ('AWE - 3-04 Descendant of Shinobi.mid', 0.9947916666666666),
#  ('021s-dangeon.mid', 0.9947916666666666),
#  ('027s-fuan.mid', 0.9947916666666666),
#  ('AWE - 2-04 On That Day, 5 Years Ago.mid', 0.9947916666666666),
#  ('XG - Bonus - Unknown 3.mid', 0.9947916666666666),
#  ('XG - 4-12 The Makou Cannon is Fired ~ ShinRa Explodes.mid',
#   0.9947916666666666),
#  ('ff9-01-32-black_waltz.mid', 0.9947916666666666),
#  ('ff3shadow.mid', 0.9947916666666666),
#  ('XG - Bonus - Unknown 2.mid', 0.9947916666666666),
#  ('075s-Gar3.mid', 0.9947916666666666),
#  ('XG - 2-04 On That Day, 5 Years Ago.mid', 0.9947916666666666),
#  ('GM - Bonus - Unknown 2.mid', 0.9947916666666666),
#  ('Ff3title.mid', 0.9947916666666666),
#  ('Ff2chfst.mid', 0.9947916666666666),
#  ('YGM - 2-05 Farm Boy.mid', 0.9947916666666666),
#  ('213-The Brink of Time.mid', 0.9947916666666666),
#  ("ff9-01-05-vivi's_theme.mid", 0.9947916666666666),
#  ('GM - 4-12 The Makou Cannon is Fired ~ ShinRa Explodes.mid',
#   0.9947916666666666),
#  ('016s-march2.mid', 0.9947916666666666),
#  ('The_Paladin.mid', 0.9947916666666666),
#  ('AWE - 1-18 Don of the Slums.mid', 0.9947916666666666),
#  ('YGM - 2-06 Waltz de Chocobo.mid', 0.9947916666666666),
#  ('ff6intld.mid', 0.9947916666666666),
#  ('201-Ruined World.mid', 0.9947916666666666),
#  ('Suspicnr.mid', 0.9947916666666666),
#  ('ff2evil.mid', 0.9947916666666666),
#  ('XG - 3-21 The Great Northern Cave.mid', 0.9947916666666666),
#  ('FF6-_Epitaph.mid', 0.9947916666666666),
#  ('YGM - 3-21 The Great Northern Cave.mid', 0.9947916666666666),
#  ('XG - 1-07 Hurry!.mid', 0.9947916666666666),
#  ('relm.mid', 0.9947916666666666),
#  ('076s-Bossbat2.mid', 0.9947916666666666),
#  ('AWE - 3-23 Who Am I.mid', 0.9947916666666666),
#  ('AWE - Bonus - Short Fanfare.mid', 0.9947916666666666),
#  ('XG - 1-23 Holding My Thoughts in My Heart.mid', 0.9947916666666666),
#  ('AWE - Bonus - FFVII Main Theme Second Half.mid', 0.9947916666666666),
#  ('GM - Bonus - Highwind Takes to the Skies Intro.mid', 0.9947916666666666),
#  ('AWE - 3-22 Reunion.mid', 0.9947916666666666),
#  ('GM - 4-02 Weapon Raid.mid', 0.9947916666666666),
#  ('110-Goodnight.mid', 0.9947916666666666),
#  ('GM - Bonus - FFVII Main Theme Second Half.mid', 0.9947916666666666),
#  ('ff2rydia.mid', 0.9947916666666666),
#  ('Ff2evil(2).mid', 0.9947916666666666),
#  ('AWE - Bonus - Highwind Takes to the Skies Intro.mid', 0.9947916666666666),
#  ('mounthob.mid', 0.9947916666666666),
#  ('AWE - 3-09 Wutai.mid', 0.9947916666666666),
#  ('GM - 3-23 Who Am I.mid', 0.9947916666666666),
#  ('GM - 3-09 Wutai.mid', 0.9947916666666666),
#  ('Figaro-2.mid', 0.9947916666666666),
#  ('GM - 2-06 Waltz de Chocobo.mid', 0.9947916666666666),
#  ('AWE - 1-22 Crazy Motorcycle.mid', 0.9947916666666666),
#  ('TR(2).mid', 0.9947916666666666),
#  ('020s-friend.mid', 0.9947916666666666),
#  ('prlde.mid', 0.9947916666666666),
#  ('GM - 2-04 On That Day, 5 Years Ago.mid', 0.9947916666666666),
#  ('XG - 2-06 Waltz de Chocobo.mid', 0.9947916666666666),
#  ('ff9-01-04-the_skies_of_alexandria.mid', 0.9947916666666666),
#  ('GM - 3-21 The Great Northern Cave .mid', 0.9947916666666666),
#  ('GM - 3-04 Descendant of Shinobi.mid', 0.9947916666666666),
#  ('049s-master.mid', 0.9947916666666666),
#  ('ff3over4.mid', 0.9947916666666666),
#  ('figaro2.mid', 0.9947916666666666),
#  ('086s-moonmv.mid', 0.9947916666666666),
#  ('YGM - Bonus - Highwind Takes to the Skies Intro.mid', 0.9947916666666666),
#  ('204-People Without a Hope.mid', 0.9947916666666666),
#  ('103-Morning Sunlight.mid', 0.9947916666666666),
#  ('XG - Bonus - Xg023.mid', 0.9947916666666666),
#  ('096s-keisho.mid', 0.9947916666666666),
#  ('XG - 3-23 Who Am I.mid', 0.9947916666666666),
#  ('YGM - 2-15 Conitnue.mid', 0.9947916666666666),
#  ('YGM - 2-04 On That Day, 5 Years Ago.mid', 0.9947916666666666),
#  ('099s-joriku2.mid', 0.9947916666666666),
#  ('ff6shap.mid', 0.9947916666666666),
#  ('012s-kani.mid', 0.9947916666666666),
#  ('magitek4.mid', 0.9947916666666666),
#  ('KIDSRUN(2).mid', 0.9947916666666666),
#  ('Ff3gogo.mid', 0.9947916666666666),
#  ('AWE - 3-21 The Great Northern Cave.mid', 0.9947916666666666),
#  ('GM - 1-07 Hurry!.mid', 0.9947916666666666),
#  ('Ff4toror.mid', 0.9947916666666666),
#  ('kidsrun.mid', 0.9947916666666666),
#  ('AWE - 1-23 Holding My Thoughts in My Heart.mid', 0.9947916666666666),
#  ('Fabul.mid', 0.9947916666666666),
#  ('YGM - 4-12 The Makou Cannon is Fired ~ ShinRa Explodes.mid',
#   0.9947916666666666),
#  ('Ff3fnfar.mid', 0.9947916666666666),
#  ('GM - 1-23 Holding My Thoughts in My Heart.mid', 0.9947916666666666),
#  ('AWE - 2-05 Farm Boy.mid', 0.9947916666666666),
#  ('YGM - Bonus - Unknown 2.mid', 0.9947916666666666),
#  ('115-Manoria Cathedral.mid', 0.9947916666666666),
#  ('YGM - Bonus - Short Fanfare.mid', 0.9947916666666666),
#  ('005s-battle.mid', 0.9947916666666666),
#  ('shadow3.mid', 0.9947916666666666),
#  ('ff9-01-13-tonight.mid', 0.9947916666666666),
#  ('XG - 1-22 Crazy Motorcycle.mid', 0.9947916666666666),
#  ('XG - 3-04 Descendant of Shinobi .mid', 0.9947916666666666),
#  ('XG - 2-15 Conitnue.mid', 0.9947916666666666),
#  ('YGM - 3-23 Who Am I.mid', 0.9947916666666666),
#  ('shadow.mid', 0.9947916666666666),
#  ('GM - 1-22 Crazy Motorcycle.mid', 0.9947916666666666),
#  ('AWE - 2-15 Continue.mid', 0.9947916666666666),
#  ("119-Frog's Theme.mid", 0.9947916666666666),
#  ('AWE - 2-06 Waltz de Chocobo.mid', 0.9947916666666666),
#  ('YGM - 1-18 Don of the Slums.mid', 0.9947916666666666),
#  ('FF6-_Victory_Fanfare.mid', 0.9947916666666666),
#  ('XG - 4-02 Weapon Raid.mid', 0.9947916666666666),
#  ('041s-field.mid', 0.9947916666666666),
#  ('YGM - 3-09 Wuati.mid', 0.9947916666666666),
#  ('120-Fanfare 1.mid', 0.9947916666666666),
#  ('018s-julia.mid', 0.9947916666666666),
#  ('Terra1.mid', 0.9947916666666666),
#  ('ff4Rydia.mid', 0.9947916666666666),
#  ('ff2_ring_of_bomb.mid', 0.9947916666666666),
#  ('Rydia.mid', 0.9947916666666666),
#  ("219-Ayla's Theme.mid", 0.9947916666666666),
#  ('GM - 2-13 Trail of Blood.mid', 0.9947916666666666),
#  ('015s-fuan2.mid', 0.9947916666666666),
#  ('XG - 3-22 Reunion.mid', 0.9947916666666666),
#  ('GM - 1-09 ShinRa Company.mid', 0.9947916666666666),
#  ('ff2bsbtl.mid', 0.9984848484848485),
#  ('Forest3.mid', 0.9985714285714286),
#  ("ff9-01-31-zidane's_theme.mid", 0.9985815602836879),
#  ('TheDecisiveBattle-v-2.mid', 0.9986631016042781),
#  ('dark.mid', 0.9986979166666666),
#  ('ff6final1.mid', 0.9988776655443322),
#  ('ff6final5.mid', 0.9994169096209913),
#  ('ff9-02-10-freyas-theme.mid', 0.9995717344753747),
#  ("ff9-02-07-quina's_theme.mid", 0.9998051441932969),
#  ('YGM - 4-04 A Secret, Sleeping in the Deep Sea.mid', 1.0),
#  ('066s-majomv.mid', 1.0),
#  ('YGM - Bonus - Ygm079.mid', 1),
#  ('FF6Final_Battle.mid', 1.0),
#  ('GM - 4-14 Jenova Absolute.mid', 1.0),
#  ('YGM - 2-18 Mining Town.mid', 1.0),
#  ('XG - 2-18 Mining Town.mid', 1.0),
#  ('ff3maina.mid', 1.0),
#  ('AWE - Bonus - Unknown 1.mid', 1.0),
#  ('Overture_Part_C.mid', 1.0),
#  ('XG - 1-01 Prelude.mid', 1.0),
#  ('ff3troop.mid', 1.0),
#  ('ff2_Illusionary_World_mid.mid', 1.0),
#  ('YGM - 1-01 Prelude.mid', 1.0),
#  ('XG - 3-18 You Can Hear the Cry of the Planet.mid', 1.0),
#  ('GM - 2-21 Sandy Badlands.mid', 1.0),
#  ('051s-rinoa.mid', 1.0),
#  ('AWE - 3-03 Great Warrior.mid', 1.0),
#  ('war.mid', 1.0),
#  ('AWE - 4-14 Jenova Absolute.mid', 1.0),
#  ('AWE - 3-16 Interupted by Fireworks.mid', 1.0),
#  ('YGM - 3-03 Great Warrior.mid', 1.0),
#  ('GM - 1-11 Fanfare.mid', 1.0),
#  ('223-Confusing Melody.mid', 1.0),
#  ('XG - Bonus - Xg061.mid', 1.0),
#  ('YGM - 4-05 Parochial Town.mid', 1.0),
#  ('061S-PUB.MID', 1.0),
#  ('FF2BattleTheme.mid', 1.0),
#  ('AWE - 4-05 Parochial Town.mid', 1.0),
#  ("XG - 3-06 The Nightmare's Beginning.mid", 1.0),
#  ('ff9-04-13-memoria.mid', 1.0),
#  ('ff3-world_of_ruin_narsh.mid', 1.0),
#  ('FFIVTroi.mid', 1.0),
#  ('WoRNarshe.mid', 1.0),
#  ('ff9-02-13-kingdom_of_burmecia.mid', 1.0),
#  ('ff9-03-04-conde_petie.mid', 1.0),
#  ('004S-RUN.MID', 1.0),
#  ('DEpitaph.mid', 1.0),
#  ('ff9-03-15-slew_of_love_letters.mid', 1.0),
#  ('XG - 1-17 Who Are You.mid', 1.0),
#  ('GM - 2-14 J-E-N-O-V-A.mid', 1.0),
#  ('YGM - 1-17 Who Are You.mid', 1.0),
#  ('GM - 3-10 Stolen Materia.mid', 1.0),
#  ('sadsong.mid', 1.0),
#  ('GM - 3-03 Great Warrior.mid', 1.0),
#  ('GM - 3-16 Interupted by Fireworks.mid', 1.0),
#  ('theme.mid', 1.0),
#  ('307-Sealed Door.mid', 1.0),
#  ('AWE - 2-14 J-E-N-O-V-A.mid', 1.0),
#  ('208-Bike Chase.mid', 1.0),
#  ('116-A Prayer to the Road that Leads.mid', 1.0),
#  ("YGM - 1-13 Turk's Theme.mid", 1.0),
#  ('AWE - 1-08 Lurking in the Darkness.mid', 1.0),
#  ('XG - 4-06 Off the Edge of Dispair.mid', 1.0),
#  ('GM - Bonus - Unknown 1.mid', 1.0),
#  ('YGM - 4-06 Off the Edge of Dispair.mid', 1.0),
#  ('empire.mid', 1.0),
#  ('ff9-03-24-sacred_grounds-esto_gaza.mid', 1.0),
#  ('ff6dancing_mad.mid', 1.0),
#  ("ff9-02-01-cid's_theme.mid", 1.0),
#  ('XG - Bonus - Unknown 1.mid', 1.0),
#  ('Ff3retrn.mid', 1.0),
#  ('AWE - 1-11 Fanfare.mid', 1.0),
#  ('Ff2moon.mid', 1.0),
#  ('XG - 3-03 Great Warrior.mid', 1.0),
#  ('kefkatow.mid', 1.0),
#  ('Blakjak.mid', 1.0),
#  ('GM - 1-08 Lurking in the Darkness.mid', 1.0),
#  ('ff6_martiallaw.mid', 1.0),
#  ('Epitaph.mid', 1.0),
#  ('ff9-03-19-the_summoned_ones.mid', 1.0),
#  ('ff9-01-20-memories_of_that_day.mid', 1.0),
#  ('YGM - 3-18 You Can Hear the Cry of the Planet.mid', 1.0),
#  ('FF3_Shadow2.mid', 1.0),
#  ('FF2-Opener.mid', 1.0),
#  ('jpr-falcon2k.mid', 1.0),
#  ('ff6-CrazyMan.mid', 1.0),
#  ('009s-waiting.mid', 1.0),
#  ('golbez.mid', 1.0),
#  ('kefkatw2.mid', 1.0),
#  ('epitaph2.mid', 1.0),
#  ('ff9-03-11-iifa_tree.mid', 1.0),
#  ('narshe3.mid', 1.0),
#  ('YGM - 2-09 Chasing the Black-Caped Man.mid', 1.0),
#  ('AWE - 4-04 A Secret, Sleeping in the Deep Sea.mid', 1.0),
#  ('AWE - 1-03 Makou Reactor.mid', 1.0),
#  ('XG - Bonus - Xg025.mid', 1.0),
#  ('Techno_de_chocobo.mid', 1.0),
#  ('figaro.mid', 1.0),
#  ('YGM - 1-03 Makou Reactor.mid', 1.0),
#  ('ff3return~1.mid', 1.0),
#  ('Tier1.mid', 1.0),
#  ('YGM - 1-11 Famfare.mid', 1.0),
#  ('059s-pinch.mid', 1.0),
#  ('ff9-02-24-eternal_harvest.mid', 1.0),
#  ('dayafter2.mid', 1.0),
#  ('025s-himitsu.mid', 1.0),
#  ('ToroiaDeChocobo.mid', 1.0),
#  ('narshe2.mid', 1.0),
#  ('Ff4golbx.mid', 1.0),
#  ('FF6_-_Techno_de_chocobo.mid', 1.0),
#  ('XG - 2-14 J-E-N-O-V-A.mid', 1.0),
#  ('figaro3.mid', 1.0),
#  ('YGM - 2-14 J-E-N-O-V-A.mid', 1.0),
#  ('ff3over5.mid', 1.0),
#  ('GM - 1-17 Who Are You.mid', 1.0),
#  ('ff6final4.mid', 1.0),
#  ('YGM - 4-14 Jenova Absolute.mid', 1.0),
#  ('055s-jail.mid', 1.0),
#  ('finalfant2.mid', 1.0),
#  ('XG - 1-08 Lurking in the Darkness.mid', 1.0),
#  ('YGM - 1-08 Lurking in the Darkness.mid', 1.0),
#  ('AWE - 4-06 Off the Edge of Dispair.mid', 1.0),
#  ('ff2lunar.mid', 1.0),
#  ('AWE - 1-01 Prelude.mid', 1.0),
#  ("AWE - 1-13 Turk's Theme.mid", 1.0),
#  ('GM - 1-04 Anxious Heart .mid', 1.0),
#  ('dvlslab.mid', 1.0),
#  ('ballad.mid', 1.0),
#  ('GM - 4-04 A Secret, Sleeping in the Deep Sea.mid', 1.0),
#  ('LunCave.mid', 1.0),
#  ('magitek3.mid', 1.0),
#  ('surprise.mid', 1.0),
#  ("203-Dome 16's Ruin.mid", 1.0),
#  ('036s-majo.mid', 1.0),
#  ('GM - 1-03 Makou Reactor.mid', 1.0),
#  ('edward2.mid', 1.0),
#  ('TerraMix.mid', 1.0),
#  ('Phantomf.mid', 1.0),
#  ('Ff6dance.mid', 1.0),
#  ('048s-horizon.mid', 1.0),
#  ('XG - 1-04 Anxious Heart.mid', 1.0),
#  ('GM - 2-18 Mining Town.mid', 1.0),
#  ('XG - 2-09 Chasing the Black-Caped Man.mid', 1.0),
#  ('Ff3kfkt1.mid', 1.0),
#  ('ff3over3.mid', 1.0),
#  ('XG - 2-16 Costa Del Sol.mid', 1.0),
#  ('owzer.mid', 1.0),
#  ('ff9-01-11-prima_vista_band.mid', 1.0),
#  ('GM - 4-06 Off the Edge of Dispair.mid', 1.0),
#  ('ff9-03-03-fossil_roo.mid', 1.0),
#  ('Phantom.mid', 1.0),
#  ('YGM - Bonus - Hearthbeat.mid', 1.0),
#  ('AWE - Bonus - Heartbeat.mid', 1.0),
#  ("ff9-02-15-kuja's_theme.mid", 1.0),
#  ('gau.mid', 1.0),
#  ('XG - 4-04 A Secret, Sleeping in the Deep Sea .mid', 1.0),
#  ('YGM - 2-21 Sandy Badlands.mid', 1.0),
#  ('Ff3figar1.mid', 1.0),
#  ('XG - 3-16 Interupted by Fireworks.mid', 1.0),
#  ('YGM - 3-16 Interupted by Fireworks.mid', 1.0),
#  ('ff2end3.mid', 1.0),
#  ('ff2dmcyn(2).mid', 1.0),
#  ('calbrena.mid', 1.0),
#  ("ff9-04-09-you're_not_alone.mid", 1.0),
#  ('085s-esta.mid', 1.0),
#  ("XG - 1-13 Turk's Theme.mid", 1.0),
#  ('ff9-02-26-extraction.mid', 1.0),
#  ('ff2-the_paladin.mid', 1.0),
#  ('XG - 4-14 Jenova Absolute.mid', 1.0),
#  ("FF6_-_Devil's_Lab.mid", 1.0),
#  ('esper2.mid', 1.0),
#  ('Espers.mid', 1.0),
#  ('YGM - Bonus - Unknown 3.mid', 1.0),
#  ('212-Fanfare 2.mid', 1.0),
#  ...]

# %%
with open('./PROP2_query_sorted_{0}.json'.format(song_filename_query.split(".")[0]), 'w') as outfile:
            json.dump({"data":nes_similarities_for_sort}, outfile)
